# %% [markdown]
# # Desafío - Inferencia de tópicos con EM
#
# ● Para realizar este desafío debes haber estudiado previamente todo el material disponibilizado correspondiente a la unidad.
#
# ● Una vez terminado el desafío, comprime la carpeta que contiene el desarrollo de los requerimientos solicitados y sube el .zip en el LMS.
#
# ● Desarrollo desafío:
#
# ○ El desafío se debe desarrollar de manera Individual.
#
# ○ Para la realización del desafío necesitarás apoyarte del archivo Apoyo Desafío - Inferencia de tópicos con EM.
#
# ## Requerimientos
#
# ● En esta sesión trabajaremos con una serie de base de datos sobre letras musicales de distintos artistas. Cada uno de los csv se encuentra en la carpeta dump.
#
# ● Cada csv tiene el nombre del artista a analizar. Los archivos contienen el nombre del artista, el género musical del artista, el nombre de la canción y las letras.
#
# ● En base a esta información, el objetivo del ejercicio es generar un modelo probabilístico que pueda identificar el género musical más probable dado la letra de una canción.
#
# ● Para ello implementaremos un modelo conocido como Latent Dirichlet Allocation que hace uso de una variante del algoritmo EM para inferir clases latentes a partir de una matriz de documentos.
#
# ## Ejercicio 1: Preparar el ambiente de trabajo
#
# ● Importe los módulos numpy, pandas, matplotlib, seaborn, glob y os siguiendo las buenas prácticas. Los últimos dos módulos permitirán realizar la importación de múltiples archivos dentro de la carpeta dump.
#
# ● Para ello genere un objeto que guarde en una lista todos los archivos alojados en dump utilizando glob.glob y   para extraer las rutas absolutas. Posteriormente genere un objeto   que contenga todos los csv.
#
# ● Asegúrese de eliminar la columna Unnamed: 0 que se genera por defecto.

# %%
# Triada calsica.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Graficos seaborn, warnings y datos perdidos.
import seaborn as sns
import warnings
import missingno as msngo

# Importaciones especificas de este desafio.
import glob, os

# Machine learning
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder, StandardScaler

# Otras librerias, configuraciones e instancias.
labelencoder = LabelEncoder()
warnings.filterwarnings('ignore')
plt.rcParams['figure.figsize'] = (20, 10)
plt.style.use('seaborn-darkgrid')

# %%
lista_csv = glob.glob('dump/*.csv')
nombres_csv = []

# %%
for i in lista_csv:
        nombres_csv.append(pd.read_csv(i, index_col = None, header = 0).drop(columns = 'Unnamed: 0'))

df_letras = pd.concat(nombres_csv)
df_letras.columns = ['Artista', 'Genero', 'Cancion', 'Letra']

# %%
df_letras.head()
# Out:
#         Artista  Genero                 Cancion  \
# 0  Public Enemy  hiphop  You're Gonna Get Yours
# 1  Public Enemy  hiphop     Sophisticated Bitch
# 2  Public Enemy  hiphop      Miuzi Weighs A Ton
# 3  Public Enemy  hiphop                Timebomb
# 4  Public Enemy  hiphop          Too Much Posse
#
#                                                Letra
# 0  (Flavor Flav) \n Oh-oh Chuck, they out to get ...
# 1  That woman in the corner, cold playin' the rol...
# 2  Yo Chuck, run a power move on them \n (Yeah) \...
# 3  (Intro - Flavor Flav) \n Hey, Chuck, we got so...
# 4  (Intro - Flavor Flav) \n What do you got to sa...

# %% [markdown]
# ## Ejercicio 2: Matriz de ocurrencias
#
# ● Importe la clase dentro de los módulos de la librería   .
#
# ● Aplique la clase para extraer las 5000 palabras más repetidas en toda la base de datos.
#
# ● Con la clase inicializada, incorpore las letras con el método fit_transform y guarde los resultados en un nuevo objeto.

# %%
# instanciamos un objeto CountVectorizer()
count_vectorizer = CountVectorizer(stop_words='english', max_features=5000)
# Implementamos los pasos fit y transform
count_vectorizer_fit = count_vectorizer.fit_transform(df_letras['Letra'])

# %%
# Extraemos tokens (palabras)
words = count_vectorizer.get_feature_names()

# %%
# extraemos frecuencia
words_freq = count_vectorizer_fit.toarray().sum(axis=0)

# %%
# creamos un nuevo dataframe
df_words = pd.DataFrame(zip(words, words_freq), columns = ['word', 'freq'])

# %%
# ordenamos por frecuencia de mayor a menor, y dejamos los primeros 5.000 registros.
df_words.sort_values(by='freq', ascending=False).iloc[0:5000, :]
# Out:
#             word   freq
# 2483        like  19629
# 1241         don  17398
# 2362        know  14962
# 1847         got  14171
# 2299        just  13978
# ...          ...    ...
# 3375          ra     31
# 2666    mattress     31
# 3796      shakes     31
# 2646      martyr     31
# 1657  footprints     31
#
# [5000 rows x 2 columns]

# %% [markdown]
# ## Ejercicio 3: Entrenamiento del Modelo
#
# ● Importe `sklearn.decomposition.LatentDirichletAllocation` y `sklearn.model_selection.GridSearchCV`.
#
# ● Genere una búsqueda de grilla con los siguientes hiper parámetros:
#
# ○ `n_components: [5, 10, 15]`.
#
# ○ `learning_decay: [0.7 y 0.5]`.
#
# ● Entrene la búsqueda de grilla con las letras en un formato vectorizado con `CountVectorizer`.
#
# ● Reporte brevemente cuál es la mejor combinación de hiper parámetros.

# %% [markdown]
# ## Digresión: Latent Dirichlet Allocation
#
# Latent Dirichlet Allocatio (LDA) es un modelo probabilístico generativo basado en Inferencia Variacional EM. La principal utilidad de esto es la identificación de tópicos en un corpus de texto. El proceso de inferencia se puede resumir en los siguientes pasos:
#
# ● Cada documento dentro del corpus se puede entender como una mezcla de tópicos comunes a nivel de corpus.
#
# ● Esta mezcla de tópicos es latente: sólo observamos los documentos registrados y sus palabras.
#
# La API de sklearn.decomposition.LatentDirichletAllocation presenta la misma funcionalidad de todo modelo de sklearn. Algunos puntos a considerar en la inicialización de la clase son:
#
# ○ n_components:Cantidaddetópicosainferirenuncorpus.
#
# ○ learning_method: Forma en la que entran los datos en entrenamiento. Cuando es 'batch', se ingresa la matriz de entrenamiento completa. Cuando es 'online', la matriz de entrenamiento ingresa de manera secuencial en parcelas pequeñas.
#
# ○ learning_decay: Tasa de aprendizaje en la función de pérdida. Cuando se implementa con learning_method='online', el modelo se entrena con Gradiente Estocástico Descendente.
#
# ○ Perplejidad: Busca aproximar el número óptimo de tópicos a inferir. Técnicamente evalúa qué tan bien predice una muestra específica. En función a un número de tópicos, define la distribución teórica de palabras representada por los tópicos y la compara con la ocurrencia empírica de palabras en tópicos.

# %%
param_grid = {'n_components': [5, 10, 15], 'learning_decay': [0.7, 0.5]}

# %%
lda = LatentDirichletAllocation(learning_method='online')

# %%
model_gridsearchcv = GridSearchCV(lda, param_grid, cv = 5, n_jobs = -1, verbose = 3)

# %%
model_gridsearchcv.fit(count_vectorizer_fit)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# GridSearchCV(cv=5,
#              estimator=LatentDirichletAllocation(learning_method='online'),
#              n_jobs=-1,
#              param_grid={'learning_decay': [0.7, 0.5],
#                          'n_components': [5, 10, 15]},
#              verbose=3)

# %%
print ('El mejor hiper parametro es: ', model_gridsearchcv.best_params_)
print ('El mejor puntaje es: ', model_gridsearchcv.best_score_)
# Out:
# El mejor hiper parametro es:  {'learning_decay': 0.7, 'n_components': 5}
# El mejor puntaje es:  -1848437.0676692799

# %% [markdown]
# ## Ejercicio 4 : Inferencia e Identificación de Tópicos
#
# ● En base a la mejor combinación de hiper parámetros, entrene el modelo con la matriz de atributos de las letras.
#
# ● Para identificar de qué se trata cada tópico, necesitamos identificar las principales 15 palabras asociadas con éste. Puede implementar la siguiente línea de código para identificar las principales palabras en un tópico:

# %%
best_param_grid = {'n_components': [5], 'learning_decay': [0.7]}

# %%
best_model_gridsearchcv = GridSearchCV(lda, best_param_grid, cv = 5, n_jobs = -1, verbose = 3)

# %%
best_model_gridsearchcv.fit(count_vectorizer_fit)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# GridSearchCV(cv=5,
#              estimator=LatentDirichletAllocation(learning_method='online'),
#              n_jobs=-1,
#              param_grid={'learning_decay': [0.7], 'n_components': [5]},
#              verbose=3)

# %%
print ('El mejor hiper parametro es: ', best_model_gridsearchcv.best_params_)
print ('El mejor puntaje es: ', best_model_gridsearchcv.best_score_)
# Out:
# El mejor hiper parametro es:  {'learning_decay': 0.7, 'n_components': 5}
# El mejor puntaje es:  -1849112.3201973184

# %%
mejor_estimador = best_model_gridsearchcv.best_estimator_

# %%
mejor_estimador
# Out:
# LatentDirichletAllocation(learning_method='online', n_components=5)

# %%
# mediante .components_ podemos extraer una matriz que entrega las distribución de palabras por cada tópico.
for topic_id, topic_name in enumerate(mejor_estimador.components_):
    # para cada tópico
    print("tópico: {}".format(topic_id + 1))
    # mediante argsort logramos ordenar los elementos por magnitud
    # para los elementos más relevantes ordenados por argsort, buscamos su correlativo
    # en la matriz dispersa y devolvemos el nombre.
    # finalmente concatenamos las palabras
    print(" ".join([count_vectorizer.get_feature_names()[i] for i in topic_name.argsort()[:-15 - 1: -1]]))
# Out:
# tópico: 1
# yeah la ah oh rock ha ba ya dance everybody whoa come boom da uh
# tópico: 2
# like got shit don ain yo know cause fuck just nigga em man niggas ya
# tópico: 3
# man like big got na little old ghostface son come head let christmas round town
# tópico: 4
# don love know just oh ll baby got yeah like let want ve gonna time
# tópico: 5
# life world god time die eyes death ll dead light blood away soul day night

# %% [markdown]
# ## Ejercicio 5: Identificación de probabilidades
#
# ● En base a la información generada, es posible identificar cuales van a ser los géneros más probables de ocurrir para un artista.
#
# ● Para ello necesitamos guardar la probabilidad de cada canción en nuestra base de datos original. Podemos implementar esto de la siguiente manera:

# %%
    # generamos una transformación de los datos a distribución de tópico por palabra en el documento
fit_best_lda = mejor_estimador.transform(count_vectorizer_fit)
    # esta transformación la podemos coaccionar a un dataframe de la siguiente manera
topics_for_each_doc = pd.DataFrame(np.round(fit_best_lda, 3),index=df_letras.index)
   # pasamos esta matriz y la redondeamos en 3 decimales
   # agregamos un índice
   #agregamos identificadores de columna
topics_for_each_doc.columns = list(map(lambda x: "T{}".format(x), range(1, mejor_estimador.n_components + 1)))
    # concatenamos las probabilidades de tópico por documento a nuestra matriz original
concatenated_df = pd.concat([df_letras, topics_for_each_doc], axis=1)
    # argmax en la matriz de tópicos
concatenated_df['highest_topic'] = np.argmax(topics_for_each_doc.values, axis=1) + 1

# %%
concatenated_df = concatenated_df.sort_values(by='Artista', ascending=True)

# %%
df_result_topic = concatenated_df[['Genero', 'T1', 'T2', 'T3', 'T4', 'T5']].groupby('Genero').mean().reset_index()
df_result_topic
# Out:
#    Genero        T1        T2        T3        T4        T5
# 0  hiphop  0.045364  0.571429  0.114880  0.163164  0.105287
# 1   metal  0.017977  0.038922  0.047808  0.169211  0.726120
# 2     pop  0.110834  0.148119  0.061557  0.559964  0.119549
# 3    rock  0.111175  0.052414  0.097247  0.475025  0.264190

# %% [markdown]
# ● Comente a qué tópicos está asociada cada clase inferida.

# %% [markdown]
# - T1, no presenta ninguna tendencia a ningun topico, por lo que los datos deben estar dispersos en otras clases
#
# - T2, tiene un 57% de pertenencia a la clase hiphop
#
# - T3, no presenta ninguna tendencia a ningun topico, por lo que los datos deben estar dispersos en otras clases
#
# - T4, tiene un 56% de pertenencia a la clase pop, pero muy seguido por rock con un 47%.
#
# - T5, tiene un 72% de pertenencia a la clase metal.

# %%
concatenated_df.head()
# Out:
#                  Artista  Genero       Cancion  \
# 16  A Tribe Called Quest  hiphop  Rap Promoter
# 59  A Tribe Called Quest  hiphop      Da Booty
# 58  A Tribe Called Quest  hiphop    Find A Way
# 57  A Tribe Called Quest  hiphop   Start It Up
# 56  A Tribe Called Quest  hiphop  Stressed Out
#
#                                                 Letra     T1     T2     T3  \
# 16  {Q-Tip} \n It's a fly love song \n To the effe...  0.093  0.557  0.207
# 59  (Q-Tip) \n Question \n What is it that everybo...  0.079  0.761  0.028
# 58  Now you caught my heart for the evening \n Kis...  0.001  0.467  0.035
# 57  (Quiet eerie voice) \n Yooooo... Yooooo... I h...  0.200  0.608  0.001
# 56  Intro./chorus \n Faith Evans: \n I really know...  0.001  0.644  0.001
#
#        T4     T5  highest_topic
# 16  0.112  0.031              2
# 59  0.025  0.108              2
# 58  0.450  0.047              2
# 57  0.120  0.071              2
# 56  0.305  0.049              2

# %%
concatenated_df.tail()
# Out:
#     Artista Genero                   Cancion  \
# 206  Weezer   rock                 Listen Up
# 205  Weezer   rock  Life Is What You Make It
# 204  Weezer   rock                  Lemonade
# 217  Weezer   rock                     Naive
# 92   Weezer   rock            The Odd Couple
#
#                                                  Letra     T1     T2     T3  \
# 206  Listen, pretty mama \n I want to be with you t...  0.178  0.003  0.003
# 205  Baby, life's what you make it \n Can't escape ...  0.007  0.007  0.007
# 204  Would you like some lemonade? \n No, this ain'...  0.004  0.004  0.058
# 217  Is this it, are we done? \n Must we carry on? ...  0.005  0.005  0.094
# 92   Unfortunately, we are not licensed to display ...  0.933  0.017  0.017
#
#         T4     T5  highest_topic
# 206  0.699  0.117              4
# 205  0.668  0.311              4
# 204  0.816  0.118              4
# 217  0.891  0.005              4
# 92   0.017  0.017              1

# %%
concatenated_df.shape
# Out:
# (9489, 10)

# %%
concatenated_df.sample(50)
# Out:
#                    Artista  Genero  \
# 126                 Eminem  hiphop
# 436              Bob Dylan    rock
# 106              The Clash    rock
# 93              De La Soul  hiphop
# 264            Nicki Minaj     pop
# 221      Bruce Springsteen    rock
# 18            Modest Mouse    rock
# 197              Bob Dylan    rock
# 45                 Mos Def  hiphop
# 25        Ghostface Killah  hiphop
# 89              De La Soul  hiphop
# 35             Spice Girls     pop
# 399      Bruce Springsteen    rock
# 107  The Smashing Pumpkins    rock
# 35   Red Hot Chili Peppers    rock
# 89                     SIA     pop
# 122              Mobb Deep  hiphop
# 73              Kanye West  hiphop
# 227            The Beatles    rock
# 149                   Rush    rock
# 158  The Smashing Pumpkins    rock
# 15                  Eminem  hiphop
# 10               Meshuggah   metal
# 80               Radiohead    rock
# 111   A Tribe Called Quest  hiphop
# 64                   Queen    rock
# 114         Kendrick Lamar  hiphop
# 251              Bob Dylan    rock
# 138           Modest Mouse    rock
# 0                 Immortal   metal
# 51              De La Soul  hiphop
# 124                 Weezer    rock
# 12                  Eminem  hiphop
# 13                  Slayer   metal
# 66                 Deicide   metal
# 67            Led Zeppelin    rock
# 33              Nickelback    rock
# 459                 Eminem  hiphop
# 18                   Queen    rock
# 46              Nickelback    rock
# 35              Pink Floyd    rock
# 62                   Queen    rock
# 98              Kanye West  hiphop
# 127                   Rush    rock
# 183       Ghostface Killah  hiphop
# 105            Iron Maiden   metal
# 133              Metallica   metal
# 10               Metallica   metal
# 252        Michael Jackson     pop
# 15         Michael Jackson     pop
#
#                                                Cancion  \
# 126                                         Big Weenie
# 436                                              Dixie
# 106                                     Are You Red..Y
# 93                                          I.C. Y'all
# 264                                         Turn Me On
# 221                                    The Big Payback
# 18                                               Might
# 197                                  Black Diamond Bay
# 45                                          Supermagic
# 25                                      Mighty Healthy
# 89                                     U Can Do (Life)
# 35            Spice Up Your Life (Murk Cuba Libre Mix)
# 399                                        Purple Rain
# 107                  The Tale Of Dusty And Pistol Pete
# 35                            Walkin' On Down The Road
# 89                                       House On Fire
# 122                                    When U Hear The
# 73                                             Monster
# 227                                Blackbird/Yesterday
# 149                             The Way The Wind Blows
# 158                            Here's To The Atom Bomb
# 15                                               Mommy
# 10                                           Sickening
# 80   The Gloaming. (Softly Open Our Mouths In The C...
# 111                                 The Low End Theory
# 64                                       Who Needs You
# 114                                        Give It 2 U
# 251          When The Night Comes Falling From The Sky
# 138               Pistol (A. Cunanan, Miami, FL. 1996)
# 0                           The Call Of The Wintermoon
# 51                                              Skit 5
# 124                                 La Mancha Screwjob
# 12                                      Low Down Dirty
# 13                                Aggressive Perfector
# 66                                      Death To Jesus
# 67                                       Carouselambra
# 33                                            Hangnail
# 459                           The Weekend - (Brooklyn)
# 18                                   Funny How Love Is
# 46                            Another Hole In The Head
# 35                                   Atom Heart Mother
# 62                                 Get Down, Make Love
# 98                                          Highlights
# 127                                The Stars Look Down
# 183                           The Sure Shot, Pts. 1- 2
# 105                                  Sign Of The Cross
# 133                                             Gymbag
# 10                                          Am I Evil?
# 252                                       Rockn' Robin
# 15                                             My Girl
#
#                                                  Letra     T1     T2     T3  \
# 126  I don't understand \n Why are you being so mea...  0.001  0.206  0.083
# 436  I wish I was in the land of cotton \n Old time...  0.004  0.004  0.004
# 106  Are you ready for \n Are you ready for \n War ...  0.003  0.166  0.083
# 93   Yeah! \n (Busta Rhymes) \n Ha ha ha-hah ha-hah...  0.161  0.682  0.082
# 264  Docta docta, need you back home, baby \n Docta...  0.001  0.059  0.001
# 221  I bought a scooter and I rented a shack \n Out...  0.077  0.522  0.170
# 18   I might \n And you might \n But neither of us ...  0.011  0.756  0.210
# 197  Up on the white veranda \n She wears a necktie...  0.001  0.118  0.282
# 45   (In Arabic) \n Bismillah ir-Rahman ir-Rahim [T...  0.065  0.437  0.053
# 25   My God, so they are killers. \n I've heard lot...  0.024  0.444  0.258
# 89   (Whispered) \n (Ah, ah) \n C'mon, c'mon, bounc...  0.151  0.613  0.042
# 35   Ha, ha (x5) \n Spice up your life! \n Ha, ha \...  0.627  0.001  0.001
# 399  I never meant to cause you any sorrow \n I nev...  0.002  0.002  0.426
# 107  Dusty screams, through doors and imaginary flo...  0.002  0.002  0.047
# 35   Well I'm walking on down the road \n But it ca...  0.196  0.096  0.002
# 89   I don't like to wait too long \n To wait too l...  0.041  0.001  0.001
# 122  Alchemist - fuck is the deal nigga? \n Uh-huh,...  0.001  0.923  0.001
# 73   Bon Iver: \n I shoot the lights out \n Hide ti...  0.042  0.679  0.059
# 227  Yesterday, all my troubles seemed so far away ...  0.003  0.003  0.003
# 149  Now it's come to this \n It's like we're back ...  0.002  0.189  0.002
# 158  Away to the side you move your head \n Gravity...  0.002  0.003  0.078
# 15   Intro: Frogg \n Whoa! \n A get your hands in t...  0.032  0.796  0.112
# 10   No one knows the soul of tears and why can't w...  0.003  0.003  0.003
# 80   Genie let out of the bottle \n It is now the w...  0.003  0.003  0.721
# 111  Q-tip: \n Let me flaunt the style (style), I t...  0.042  0.760  0.033
# 64   I make it half past six you come at seven \n A...  0.002  0.002  0.110
# 114  Yeah, huh \n Yeah, baby baby \n Yeah, baby bab...  0.172  0.166  0.113
# 251  Look out across the fields, see me returning \...  0.001  0.001  0.001
# 138  I've got my pistol in the car, uh huh \n I've ...  0.162  0.002  0.401
# 0    Buried beneath the mountains of frost \n Years...  0.003  0.003  0.026
# 51   "That's it? \n That's all? \n Van \n Damme! \n...  0.081  0.720  0.008
# 124  Unfortunately, we are not licensed to display ...  0.933  0.017  0.017
# 12   Warning, this shit's gon be rated R, restricte...  0.010  0.667  0.105
# 13   Follow me, I'll lead the way, Your fears will ...  0.004  0.004  0.004
# 66   Calvary's son what have you done, Nothing but ...  0.002  0.031  0.002
# 67   Sisters of the way-side bide their time in qui...  0.148  0.001  0.113
# 33   My hopes just fell and I can't see \n The reas...  0.002  0.167  0.002
# 459  I'm in the zone \n Don't feel like stayin' hom...  0.002  0.643  0.002
# 18   Funny how love is everywhere just look and see...  0.002  0.002  0.002
# 46   I'm through thinking of things to say to you \...  0.001  0.001  0.001
# 35   a) Father's Shout \n instrumental \n b) Breast...  0.762  0.076  0.100
# 62   Get down, make love \n Get down, make love \n ...  0.033  0.002  0.021
# 98   (Young Thug and Kanye West) \n High lights \n ...  0.081  0.417  0.035
# 127  Like the fly on the wheel, who says \n "What a...  0.003  0.003  0.003
# 183  Record spins, I'm going in \n I don't shoot to...  0.012  0.362  0.318
# 105  Eleven saintly shrouded men \n Silhouettes sta...  0.002  0.002  0.002
# 133  When the words have all been said \n When you ...  0.411  0.003  0.292
# 10   My mother was a witch, she was burned alive \n...  0.002  0.110  0.111
# 252  He rocks in the tree tops all day long \n Hopp...  0.359  0.001  0.424
# 15   I've got sunshine \n On a cloudy day \n When i...  0.003  0.003  0.003
#
#         T4     T5  highest_topic
# 126  0.689  0.021              4
# 436  0.004  0.986              5
# 106  0.003  0.745              5
# 93   0.001  0.074              2
# 264  0.801  0.138              4
# 221  0.189  0.041              2
# 18   0.011  0.011              2
# 197  0.273  0.325              5
# 45   0.125  0.320              2
# 25   0.001  0.273              2
# 89   0.020  0.174              2
# 35   0.333  0.038              1
# 399  0.349  0.220              3
# 107  0.181  0.767              5
# 35   0.641  0.065              4
# 89   0.720  0.236              4
# 122  0.074  0.001              2
# 73   0.119  0.101              2
# 227  0.956  0.034              4
# 149  0.002  0.806              5
# 158  0.289  0.628              5
# 15   0.001  0.059              2
# 10   0.003  0.989              5
# 80   0.003  0.269              3
# 111  0.127  0.038              2
# 64   0.533  0.352              4
# 114  0.548  0.001              4
# 251  0.475  0.521              5
# 138  0.433  0.002              4
# 0    0.003  0.964              5
# 51   0.008  0.182              2
# 124  0.017  0.017              1
# 12   0.096  0.121              2
# 13   0.345  0.644              5
# 66   0.002  0.963              5
# 67   0.130  0.607              5
# 33   0.595  0.235              4
# 459  0.270  0.083              2
# 18   0.917  0.077              4
# 46   0.775  0.221              4
# 35   0.023  0.038              1
# 62   0.943  0.002              4
# 98   0.467  0.001              4
# 127  0.436  0.554              5
# 183  0.001  0.307              2
# 105  0.002  0.993              5
# 133  0.003  0.291              1
# 10   0.218  0.560              5
# 252  0.213  0.001              3
# 15   0.990  0.003              4

# %% [markdown]
# ● Genere una matriz de correlaciones entre la probabilidad de tópicos inferidos. Comente brevemente cuales son las principales asociaciones existentes.
#
# ● Con esta nueva base de datos, identifique las probabilidades de pertenencia para un artista específico.
#
# ● Grafique la distribución de las probabilidades para algún artista en específico.

# %%
def selec_df_artist(df, artista):
        return df[df['Artista'] == artista].loc[:, 'T1':'T5']

# %%
dualipa_df = selec_df_artist(concatenated_df, 'Dua Lipa')
dualipa_df.shape
# Out:
# (29, 5)

# %%
dualipa_df.mean()
# Out:
# T1    0.034517
# T2    0.094345
# T3    0.020793
# T4    0.696828
# T5    0.153345
# dtype: float64

# %%
# Correlacion de topicos para Dua Lipa
sns.heatmap(dualipa_df.corr(), annot=True, cmap='Blues')
# Out:
# <AxesSubplot:>
# [CV 2/5] END learning_decay=0.7, n_components=10;, score=-1913657.848 total time= 1.5min
# [CV 4/5] END learning_decay=0.7, n_components=15;, score=-1776894.766 total time= 1.5min
# [CV 3/5] END learning_decay=0.5, n_components=10;, score=-1940647.440 total time= 1.1min
# [CV 1/5] END learning_decay=0.7, n_components=5;, score=-2012455.192 total time=  51.2s

# %%
for col in dualipa_df.columns:
        plt.rcParams['figure.figsize'] = (8, 6)
        sns.scatterplot(data = dualipa_df[col])
        plt.title(f'Probabilidades para la banda {"Dua Lipa"} considerando el tópico {col}')
        plt.ylabel('Pertenencia a uno de los tópicos')
        plt.xlabel('Observaciónes')
        plt.show()
# Out:
# [CV 3/5] END learning_decay=0.7, n_components=10;, score=-1944293.009 total time= 1.5min
# [CV 3/5] END learning_decay=0.7, n_components=15;, score=-1954776.920 total time= 1.4min
# [CV 2/5] END learning_decay=0.5, n_components=10;, score=-1915233.172 total time= 1.1min
# [CV 5/5] END learning_decay=0.5, n_components=15;, score=-1677451.430 total time=  49.6s
# [CV 5/5] END learning_decay=0.7, n_components=5;, score=-1657593.026 total time=  54.8s
# [CV 5/5] END learning_decay=0.7, n_components=5;, score=-1661897.876 total time= 1.6min
# [CV 5/5] END learning_decay=0.7, n_components=15;, score=-1680280.413 total time= 1.5min
# [CV 4/5] END learning_decay=0.5, n_components=10;, score=-1756268.535 total time= 1.1min
# [CV 4/5] END learning_decay=0.7, n_components=5;, score=-1745216.484 total time=  56.9s
# [CV 1/5] END learning_decay=0.7, n_components=5;, score=-2008014.564 total time= 1.4min
# [CV 5/5] END learning_decay=0.7, n_components=10;, score=-1672737.047 total time= 1.5min
# [CV 5/5] END learning_decay=0.5, n_components=5;, score=-1654100.685 total time= 1.1min
# [CV 3/5] END learning_decay=0.5, n_components=15;, score=-1947595.351 total time=  53.8s
# [CV 2/5] END learning_decay=0.7, n_components=5;, score=-1896858.529 total time=  58.7s
# [CV 4/5] END learning_decay=0.7, n_components=5;, score=-1748174.040 total time= 1.5min
# [CV 2/5] END learning_decay=0.7, n_components=15;, score=-1920988.833 total time= 1.5min
# [CV 1/5] END learning_decay=0.5, n_components=10;, score=-2033859.744 total time= 1.1min
# [CV 4/5] END learning_decay=0.5, n_components=15;, score=-1772779.632 total time=  53.2s
# [CV 3/5] END learning_decay=0.7, n_components=5;, score=-1933438.370 total time=  58.9s

# %% [markdown]
# Se puede observar que Dua Lipa tiene mayor porcentaje de pertenencia al topicos T4, con un 69% de pertenencia al topico.

# %%
Eminem_df = selec_df_artist(concatenated_df, 'Eminem')
Eminem_df.shape
# Out:
# (493, 5)

# %%
Eminem_df.mean()
# Out:
# T1    0.031010
# T2    0.567110
# T3    0.082819
# T4    0.225535
# T5    0.093641
# dtype: float64

# %%
# Correlacion de topicos para Eminem
sns.heatmap(Eminem_df.corr(), annot=True, cmap='Blues')
# Out:
# <AxesSubplot:>

# %%
for col in Eminem_df.columns:
        plt.rcParams['figure.figsize'] = (8, 6)
        sns.scatterplot(data = Eminem_df[col])
        plt.title(f'Probabilidades para la banda {"Eminem"} considerando el tópico {col}')
        plt.ylabel('Pertenencia a uno de los tópicos')
        plt.xlabel('Observaciónes')
        plt.show()

# %%
Se puede observar que Eminem tiene mayor porcentaje de pertenencia al topicos T2, con un 56% de pertenencia al topico.
